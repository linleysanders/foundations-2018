# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://arlweb.msha.gov/drs/drshome.htm')

# %%
text_input = driver.find_element_by_name("OperSearch")

# %%
text_input.send_keys('dirt')

# %%
button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
button.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# > - *Tip: `.text` will help you here.*
# > - *Tip: You aren't interesting in annotations or anything, just mines and where they are from*
# > - *Tip: Using `print("-----")` will help you keep track of different rows*
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third. You can use this to skip ahead to the 'good' data if you want*

# %%
dirt_oper = driver.find_elements_by_tag_name('tr')

for operators in dirt_oper[7:]:
    print(operators.text)
    print("-----")
# Out:
# 3503598
# OR  Newberg Rock & Dirt   Newberg Rock & Dirt Surface M  Active  Crushed, Broken Stone NEC
# -----
# 1401575
# KS  Bender Sand & Dirt   BENDER SAND & DIRT Surface M  Intermittent  Construction Sand and Gravel
# -----
# 5001797
# AK  Dirt Company   Bush Pilot Surface M  Intermittent  Construction Sand and Gravel
# -----
# 2103723
# MN  Dirt Doctor Inc   Rock Lake Plant Surface M  Intermittent  Construction Sand and Gravel
# -----
# 2103914
# MN  Dirt Work Specialists LLC   Astec Plant Surface M  Intermittent  Construction Sand and Gravel
# -----
# 4104757
# TX  Dirt Works   Portable #1 Surface M  Intermittent  Construction Sand and Gravel
# -----
# 0801306
# FL  Holley Dirt Company, Inc   River Road Pit Surface M  Active  Sand, Common
# -----
# 3901432
# SD  Krueger Brothers Gravel & Dirt   PORTABLE SCREENER Surface M  Intermittent  Construction Sand and Gravel
# -----
# 3609624
# PA  M R Dirt   Forbes Pit Surface M  Temporarily Idled  Construction Sand and Gravel
# -----
# 3609931
# PA  M.R. Dirt Inc.   Camptown Quarry Surface M  Intermittent  Dimension Stone NEC
# -----
# 1519799
# KY  P B Dirt Movers, Inc   Fedscreek Surface Surface C  Active  Coal (Bituminous)
# -----
# 4407379
# VA  P B Dirt Movers, Inc.   No. 3 Surface C  New Mine
# -----
# 4407296
# VA  PB Dirt Movers   Mine No. 6 Underground C  Temporarily Idled  Coal (Bituminous)
# -----
# 0203332
# AZ  Prescott Dirt, LLC   Sandretto Drive Surface M  Intermittent  Construction Sand and Gravel
# -----
# 2901986
# NM  R D Blankenship Dirt Work LLC   R D BLANKENSHIP DIRT WORK Surface M  Active  Construction Sand and Gravel
# -----
# 0801417
# FL  Sand & Dirt, Inc   Molino Pit Surface M  Active  Sand, Common
# -----
# 4300768
# VT  SIMPSON DIRTWORX LLC   Pettibone Jaw Crusher Surface M  Intermittent  Construction Sand and Gravel
# -----
# 4300776
# VT  SIMPSON DIRTWORX LLC   Chieftan 1400 Surface M  Intermittent  Construction Sand and Gravel
# -----
# 2302283
# MO  Spry's Dirt & Gravel, Inc.   Mike's Money Pit Surface M  Intermittent  Construction Sand and Gravel
# -----
# 2103518
# MN  Vogt Dirt Service   Crusher Surface M  Intermittent  Construction Sand and Gravel
# -----
# Total Number of Mines Found:  20
# -----

# %%
rows = driver.find_elements_by_tag_name('tr')
dop_list = []

for row in rows[7:-1]:
    cells = row.find_elements_by_tag_name('td')
    print("---")

    dop_dict = {}
    
    dop_dict['operator'] = cells[2].text
    
    dop_dict['mine name'] = cells[3].text
    
    dop_dict['commodity'] = cells[7].text
    
    print("Dictionary looks like", dop_dict)

    dop_list.append(dop_dict)
# Out:
# ---
# Dictionary looks like {'operator': 'Newberg Rock & Dirt  ', 'mine name': 'Newberg Rock & Dirt', 'commodity': 'Crushed, Broken Stone NEC '}
# ---
# Dictionary looks like {'operator': 'Bender Sand & Dirt  ', 'mine name': 'BENDER SAND & DIRT', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'Dirt Company  ', 'mine name': 'Bush Pilot', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'Dirt Doctor Inc  ', 'mine name': 'Rock Lake Plant', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'Dirt Work Specialists LLC  ', 'mine name': 'Astec Plant', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'Dirt Works  ', 'mine name': 'Portable #1', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'Holley Dirt Company, Inc  ', 'mine name': 'River Road Pit', 'commodity': 'Sand, Common '}
# ---
# Dictionary looks like {'operator': 'Krueger Brothers Gravel & Dirt  ', 'mine name': 'PORTABLE SCREENER', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'M R Dirt  ', 'mine name': 'Forbes Pit', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'M.R. Dirt Inc.  ', 'mine name': 'Camptown Quarry', 'commodity': 'Dimension Stone NEC '}
# ---
# Dictionary looks like {'operator': 'P B Dirt Movers, Inc  ', 'mine name': 'Fedscreek Surface', 'commodity': 'Coal (Bituminous) '}
# ---
# Dictionary looks like {'operator': 'P B Dirt Movers, Inc.  ', 'mine name': 'No. 3', 'commodity': ' '}
# ---
# Dictionary looks like {'operator': 'PB Dirt Movers  ', 'mine name': 'Mine No. 6', 'commodity': 'Coal (Bituminous) '}
# ---
# Dictionary looks like {'operator': 'Prescott Dirt, LLC  ', 'mine name': 'Sandretto Drive', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'R D Blankenship Dirt Work LLC  ', 'mine name': 'R D BLANKENSHIP DIRT WORK', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'Sand & Dirt, Inc  ', 'mine name': 'Molino Pit', 'commodity': 'Sand, Common '}
# ---
# Dictionary looks like {'operator': 'SIMPSON DIRTWORX LLC  ', 'mine name': 'Pettibone Jaw Crusher', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'SIMPSON DIRTWORX LLC  ', 'mine name': 'Chieftan 1400', 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': "Spry's Dirt & Gravel, Inc.  ", 'mine name': "Mike's Money Pit", 'commodity': 'Construction Sand and Gravel '}
# ---
# Dictionary looks like {'operator': 'Vogt Dirt Service  ', 'mine name': 'Crusher', 'commodity': 'Construction Sand and Gravel '}

# %%
import pandas as pd

df = pd.DataFrame(rows)

df.to_csv("dirt-operators.csv", index=False)

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third.*
# > - *Tip: You can use list slicing or an `if` statement to skip the non-data row(s). List slicing is probably easier, even if you aren't comfortable with it.*
# > - *Tip: or honestly you can use `try` and `except` if you know how it works.*
# > - *Tip: Once you have the "right" rows of data, you're going to be looking for a certain tag inside*
# > - *Tip: Sometimes you can't say "give me this class," and instead you have to say "give me all of the `div` elements, and then give me the third one."*

# %%
rows = driver.find_elements_by_tag_name('tr')
op_list = []

for row in rows[7:-1]:
    cells = row.find_elements_by_tag_name('td')

    op_dict = {}
    
    op_dict['operator'] = cells[2].text
    
    print(op_dict)

    op_list.append(op_dict)
# Out:
# {'operator': 'Newberg Rock & Dirt  '}
# {'operator': 'Bender Sand & Dirt  '}
# {'operator': 'Dirt Company  '}
# {'operator': 'Dirt Doctor Inc  '}
# {'operator': 'Dirt Work Specialists LLC  '}
# {'operator': 'Dirt Works  '}
# {'operator': 'Holley Dirt Company, Inc  '}
# {'operator': 'Krueger Brothers Gravel & Dirt  '}
# {'operator': 'M R Dirt  '}
# {'operator': 'M.R. Dirt Inc.  '}
# {'operator': 'P B Dirt Movers, Inc  '}
# {'operator': 'P B Dirt Movers, Inc.  '}
# {'operator': 'PB Dirt Movers  '}
# {'operator': 'Prescott Dirt, LLC  '}
# {'operator': 'R D Blankenship Dirt Work LLC  '}
# {'operator': 'Sand & Dirt, Inc  '}
# {'operator': 'SIMPSON DIRTWORX LLC  '}
# {'operator': 'SIMPSON DIRTWORX LLC  '}
# {'operator': "Spry's Dirt & Gravel, Inc.  "}
# {'operator': 'Vogt Dirt Service  '}

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
rows = driver.find_elements_by_tag_name('tr')
id_list = []

for row in rows[7:-1]:
    cells = row.find_elements_by_tag_name('td')

    id_dict = {}
    
    id_dict['ID'] = cells[0].text
    
    print(id_dict)

    id_list.append(id_dict)
# Out:
# {'ID': '3503598'}
# {'ID': '1401575'}
# {'ID': '5001797'}
# {'ID': '2103723'}
# {'ID': '2103914'}
# {'ID': '4104757'}
# {'ID': '0801306'}
# {'ID': '3901432'}
# {'ID': '3609624'}
# {'ID': '3609931'}
# {'ID': '1519799'}
# {'ID': '4407379'}
# {'ID': '4407296'}
# {'ID': '0203332'}
# {'ID': '2901986'}
# {'ID': '0801417'}
# {'ID': '4300768'}
# {'ID': '4300776'}
# {'ID': '2302283'}
# {'ID': '2103518'}

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.
#
# > - *Tip: Start with an empty dictionary, then add the keys one at a time like we did during class*
# > - *Tip: You might want to save all of the cells in a variable, then use indexes to get the second, third, fourth, etc.*
# > - *Tip: I know you already skipped a bunch of rows already, but one of them still might be bad! Which one is it? How can you skip it? You might need to slice out some of the end of your list, too. Use `print` to help you debug, or just look at the page closely.*
# > - *Tip: Or, if you did the other homework already, `try` / `except` is also an option*

# %%
rows = driver.find_elements_by_tag_name('tr')

for row in rows[7:-1]:
    cells = row.find_elements_by_tag_name('td')
    print("---")
    
    operator_ID = {}
    operator_name = {}
    mine_name = {}
    state = {}
    mine_type = {}
    coal_or_metal = {}
    status = {}
    commodity = {}

    operator_ID['ID'] = cells[0].text
    print(operator_ID)
    final_list.append(operator_ID)
    
    operator_name['Operator'] = cells[2].text
    print(operator_name)
    final_list.append(operator_name)

    mine_name['Mine Name'] = cells[3].text
    print(mine_name)
    final_list.append(mine_name)
    
    state['State'] = cells[1].text
    print(state)
    final_list.append(state)
    
    mine_type['Mine Type'] = cells[4].text
    print(mine_type)
    final_list.append(mine_type)
    
    result = coal_or_metal['Coal or Metal'] = cells[5].text
    final_list.append(coal_or_metal)
    print(coal_or_metal) 
    if result == ('M '):
        print("This mine produces Metal")
    else:
        print("This mine produces Coal")
       
    status['Status'] = cells[6].text
    print(status)
    final_list.append(status)
    
    commodity['Commodity'] = cells[7].text
    print(commodity)
    final_list.append(commodity)
# Out:
# ---
# {'ID': '3503598'}
# {'Operator': 'Newberg Rock & Dirt  '}
# {'Mine Name': 'Newberg Rock & Dirt'}
# {'State': 'OR '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Active '}
# {'Commodity': 'Crushed, Broken Stone NEC '}
# {}
# ---
# {'ID': '1401575'}
# {'Operator': 'Bender Sand & Dirt  '}
# {'Mine Name': 'BENDER SAND & DIRT'}
# {'State': 'KS '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '5001797'}
# {'Operator': 'Dirt Company  '}
# {'Mine Name': 'Bush Pilot'}
# {'State': 'AK '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '2103723'}
# {'Operator': 'Dirt Doctor Inc  '}
# {'Mine Name': 'Rock Lake Plant'}
# {'State': 'MN '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '2103914'}
# {'Operator': 'Dirt Work Specialists LLC  '}
# {'Mine Name': 'Astec Plant'}
# {'State': 'MN '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '4104757'}
# {'Operator': 'Dirt Works  '}
# {'Mine Name': 'Portable #1'}
# {'State': 'TX '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '0801306'}
# {'Operator': 'Holley Dirt Company, Inc  '}
# {'Mine Name': 'River Road Pit'}
# {'State': 'FL '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Active '}
# {'Commodity': 'Sand, Common '}
# {}
# ---
# {'ID': '3901432'}
# {'Operator': 'Krueger Brothers Gravel & Dirt  '}
# {'Mine Name': 'PORTABLE SCREENER'}
# {'State': 'SD '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '3609624'}
# {'Operator': 'M R Dirt  '}
# {'Mine Name': 'Forbes Pit'}
# {'State': 'PA '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Temporarily Idled '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '3609931'}
# {'Operator': 'M.R. Dirt Inc.  '}
# {'Mine Name': 'Camptown Quarry'}
# {'State': 'PA '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Dimension Stone NEC '}
# {}
# ---
# {'ID': '1519799'}
# {'Operator': 'P B Dirt Movers, Inc  '}
# {'Mine Name': 'Fedscreek Surface'}
# {'State': 'KY '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'C '}
# This mine produces Coal
# {'Status': 'Active '}
# {'Commodity': 'Coal (Bituminous) '}
# {}
# ---
# {'ID': '4407379'}
# {'Operator': 'P B Dirt Movers, Inc.  '}
# {'Mine Name': 'No. 3'}
# {'State': 'VA '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'C '}
# This mine produces Coal
# {'Status': 'New Mine '}
# {'Commodity': ' '}
# {}
# ---
# {'ID': '4407296'}
# {'Operator': 'PB Dirt Movers  '}
# {'Mine Name': 'Mine No. 6'}
# {'State': 'VA '}
# {'Mine Type': 'Underground'}
# {'Coal or Metal': 'C '}
# This mine produces Coal
# {'Status': 'Temporarily Idled '}
# {'Commodity': 'Coal (Bituminous) '}
# {}
# ---
# {'ID': '0203332'}
# {'Operator': 'Prescott Dirt, LLC  '}
# {'Mine Name': 'Sandretto Drive'}
# {'State': 'AZ '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '2901986'}
# {'Operator': 'R D Blankenship Dirt Work LLC  '}
# {'Mine Name': 'R D BLANKENSHIP DIRT WORK'}
# {'State': 'NM '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Active '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '0801417'}
# {'Operator': 'Sand & Dirt, Inc  '}
# {'Mine Name': 'Molino Pit'}
# {'State': 'FL '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Active '}
# {'Commodity': 'Sand, Common '}
# {}
# ---
# {'ID': '4300768'}
# {'Operator': 'SIMPSON DIRTWORX LLC  '}
# {'Mine Name': 'Pettibone Jaw Crusher'}
# {'State': 'VT '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '4300776'}
# {'Operator': 'SIMPSON DIRTWORX LLC  '}
# {'Mine Name': 'Chieftan 1400'}
# {'State': 'VT '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '2302283'}
# {'Operator': "Spry's Dirt & Gravel, Inc.  "}
# {'Mine Name': "Mike's Money Pit"}
# {'State': 'MO '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}
# ---
# {'ID': '2103518'}
# {'Operator': 'Vogt Dirt Service  '}
# {'Mine Name': 'Crusher'}
# {'State': 'MN '}
# {'Mine Type': 'Surface'}
# {'Coal or Metal': 'M '}
# This mine produces Metal
# {'Status': 'Intermittent '}
# {'Commodity': 'Construction Sand and Gravel '}
# {}

# %%
final_list
# Out:
# [{'ID': '3503598'},
#  {'Operator': 'Newberg Rock & Dirt  '},
#  {'Mine Name': 'Newberg Rock & Dirt'},
#  {'State': 'OR '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Active '},
#  {'Commodity': 'Crushed, Broken Stone NEC '},
#  {},
#  {'ID': '1401575'},
#  {'Operator': 'Bender Sand & Dirt  '},
#  {'Mine Name': 'BENDER SAND & DIRT'},
#  {'State': 'KS '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '5001797'},
#  {'Operator': 'Dirt Company  '},
#  {'Mine Name': 'Bush Pilot'},
#  {'State': 'AK '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '2103723'},
#  {'Operator': 'Dirt Doctor Inc  '},
#  {'Mine Name': 'Rock Lake Plant'},
#  {'State': 'MN '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '2103914'},
#  {'Operator': 'Dirt Work Specialists LLC  '},
#  {'Mine Name': 'Astec Plant'},
#  {'State': 'MN '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '4104757'},
#  {'Operator': 'Dirt Works  '},
#  {'Mine Name': 'Portable #1'},
#  {'State': 'TX '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '0801306'},
#  {'Operator': 'Holley Dirt Company, Inc  '},
#  {'Mine Name': 'River Road Pit'},
#  {'State': 'FL '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Active '},
#  {'Commodity': 'Sand, Common '},
#  {},
#  {'ID': '3901432'},
#  {'Operator': 'Krueger Brothers Gravel & Dirt  '},
#  {'Mine Name': 'PORTABLE SCREENER'},
#  {'State': 'SD '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '3609624'},
#  {'Operator': 'M R Dirt  '},
#  {'Mine Name': 'Forbes Pit'},
#  {'State': 'PA '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Temporarily Idled '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '3609931'},
#  {'Operator': 'M.R. Dirt Inc.  '},
#  {'Mine Name': 'Camptown Quarry'},
#  {'State': 'PA '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Dimension Stone NEC '},
#  {},
#  {'ID': '1519799'},
#  {'Operator': 'P B Dirt Movers, Inc  '},
#  {'Mine Name': 'Fedscreek Surface'},
#  {'State': 'KY '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'C '},
#  {'Status': 'Active '},
#  {'Commodity': 'Coal (Bituminous) '},
#  {},
#  {'ID': '4407379'},
#  {'Operator': 'P B Dirt Movers, Inc.  '},
#  {'Mine Name': 'No. 3'},
#  {'State': 'VA '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'C '},
#  {'Status': 'New Mine '},
#  {'Commodity': ' '},
#  {},
#  {'ID': '4407296'},
#  {'Operator': 'PB Dirt Movers  '},
#  {'Mine Name': 'Mine No. 6'},
#  {'State': 'VA '},
#  {'Mine Type': 'Underground'},
#  {'Coal or Metal': 'C '},
#  {'Status': 'Temporarily Idled '},
#  {'Commodity': 'Coal (Bituminous) '},
#  {},
#  {'ID': '0203332'},
#  {'Operator': 'Prescott Dirt, LLC  '},
#  {'Mine Name': 'Sandretto Drive'},
#  {'State': 'AZ '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '2901986'},
#  {'Operator': 'R D Blankenship Dirt Work LLC  '},
#  {'Mine Name': 'R D BLANKENSHIP DIRT WORK'},
#  {'State': 'NM '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Active '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '0801417'},
#  {'Operator': 'Sand & Dirt, Inc  '},
#  {'Mine Name': 'Molino Pit'},
#  {'State': 'FL '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Active '},
#  {'Commodity': 'Sand, Common '},
#  {},
#  {'ID': '4300768'},
#  {'Operator': 'SIMPSON DIRTWORX LLC  '},
#  {'Mine Name': 'Pettibone Jaw Crusher'},
#  {'State': 'VT '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '4300776'},
#  {'Operator': 'SIMPSON DIRTWORX LLC  '},
#  {'Mine Name': 'Chieftan 1400'},
#  {'State': 'VT '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '2302283'},
#  {'Operator': "Spry's Dirt & Gravel, Inc.  "},
#  {'Mine Name': "Mike's Money Pit"},
#  {'State': 'MO '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {},
#  {'ID': '2103518'},
#  {'Operator': 'Vogt Dirt Service  '},
#  {'Mine Name': 'Crusher'},
#  {'State': 'MN '},
#  {'Mine Type': 'Surface'},
#  {'Coal or Metal': 'M '},
#  {'Status': 'Intermittent '},
#  {'Commodity': 'Construction Sand and Gravel '},
#  {}]

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
import pandas as pd

# %%
df = pd.DataFrame(final_list)

# %%
df
# Out:
#     Coal or Metal                      Commodity         ID  \
# 0             NaN                            NaN  3503598.0
# 1             NaN                            NaN        NaN
# 2             NaN                            NaN        NaN
# 3             NaN                            NaN        NaN
# 4             NaN                            NaN        NaN
# 5              M                             NaN        NaN
# 6             NaN                            NaN        NaN
# 7             NaN     Crushed, Broken Stone NEC         NaN
# 8             NaN                            NaN        NaN
# 9             NaN                            NaN  1401575.0
# 10            NaN                            NaN        NaN
# 11            NaN                            NaN        NaN
# 12            NaN                            NaN        NaN
# 13            NaN                            NaN        NaN
# 14             M                             NaN        NaN
# 15            NaN                            NaN        NaN
# 16            NaN  Construction Sand and Gravel         NaN
# 17            NaN                            NaN        NaN
# 18            NaN                            NaN  5001797.0
# 19            NaN                            NaN        NaN
# 20            NaN                            NaN        NaN
# 21            NaN                            NaN        NaN
# 22            NaN                            NaN        NaN
# 23             M                             NaN        NaN
# 24            NaN                            NaN        NaN
# 25            NaN  Construction Sand and Gravel         NaN
# 26            NaN                            NaN        NaN
# 27            NaN                            NaN  2103723.0
# 28            NaN                            NaN        NaN
# 29            NaN                            NaN        NaN
# ..            ...                            ...        ...
# 150           NaN                            NaN        NaN
# 151           NaN  Construction Sand and Gravel         NaN
# 152           NaN                            NaN        NaN
# 153           NaN                            NaN  4300776.0
# 154           NaN                            NaN        NaN
# 155           NaN                            NaN        NaN
# 156           NaN                            NaN        NaN
# 157           NaN                            NaN        NaN
# 158            M                             NaN        NaN
# 159           NaN                            NaN        NaN
# 160           NaN  Construction Sand and Gravel         NaN
# 161           NaN                            NaN        NaN
# 162           NaN                            NaN  2302283.0
# 163           NaN                            NaN        NaN
# 164           NaN                            NaN        NaN
# 165           NaN                            NaN        NaN
# 166           NaN                            NaN        NaN
# 167            M                             NaN        NaN
# 168           NaN                            NaN        NaN
# 169           NaN  Construction Sand and Gravel         NaN
# 170           NaN                            NaN        NaN
# 171           NaN                            NaN  2103518.0
# 172           NaN                            NaN        NaN
# 173           NaN                            NaN        NaN
# 174           NaN                            NaN        NaN
# 175           NaN                            NaN        NaN
# 176            M                             NaN        NaN
# 177           NaN                            NaN        NaN
# 178           NaN  Construction Sand and Gravel         NaN
# 179           NaN                            NaN        NaN
#
#                Mine Name Mine Type                      Operator State  \
# 0                    NaN       NaN                           NaN   NaN
# 1                    NaN       NaN         Newberg Rock & Dirt     NaN
# 2    Newberg Rock & Dirt       NaN                           NaN   NaN
# 3                    NaN       NaN                           NaN   OR
# 4                    NaN   Surface                           NaN   NaN
# 5                    NaN       NaN                           NaN   NaN
# 6                    NaN       NaN                           NaN   NaN
# 7                    NaN       NaN                           NaN   NaN
# 8                    NaN       NaN                           NaN   NaN
# 9                    NaN       NaN                           NaN   NaN
# 10                   NaN       NaN          Bender Sand & Dirt     NaN
# 11    BENDER SAND & DIRT       NaN                           NaN   NaN
# 12                   NaN       NaN                           NaN   KS
# 13                   NaN   Surface                           NaN   NaN
# 14                   NaN       NaN                           NaN   NaN
# 15                   NaN       NaN                           NaN   NaN
# 16                   NaN       NaN                           NaN   NaN
# 17                   NaN       NaN                           NaN   NaN
# 18                   NaN       NaN                           NaN   NaN
# 19                   NaN       NaN                Dirt Company     NaN
# 20            Bush Pilot       NaN                           NaN   NaN
# 21                   NaN       NaN                           NaN   AK
# 22                   NaN   Surface                           NaN   NaN
# 23                   NaN       NaN                           NaN   NaN
# 24                   NaN       NaN                           NaN   NaN
# 25                   NaN       NaN                           NaN   NaN
# 26                   NaN       NaN                           NaN   NaN
# 27                   NaN       NaN                           NaN   NaN
# 28                   NaN       NaN             Dirt Doctor Inc     NaN
# 29       Rock Lake Plant       NaN                           NaN   NaN
# ..                   ...       ...                           ...   ...
# 150                  NaN       NaN                           NaN   NaN
# 151                  NaN       NaN                           NaN   NaN
# 152                  NaN       NaN                           NaN   NaN
# 153                  NaN       NaN                           NaN   NaN
# 154                  NaN       NaN        SIMPSON DIRTWORX LLC     NaN
# 155        Chieftan 1400       NaN                           NaN   NaN
# 156                  NaN       NaN                           NaN   VT
# 157                  NaN   Surface                           NaN   NaN
# 158                  NaN       NaN                           NaN   NaN
# 159                  NaN       NaN                           NaN   NaN
# 160                  NaN       NaN                           NaN   NaN
# 161                  NaN       NaN                           NaN   NaN
# 162                  NaN       NaN                           NaN   NaN
# 163                  NaN       NaN  Spry's Dirt & Gravel, Inc.     NaN
# 164     Mike's Money Pit       NaN                           NaN   NaN
# 165                  NaN       NaN                           NaN   MO
# 166                  NaN   Surface                           NaN   NaN
# 167                  NaN       NaN                           NaN   NaN
# 168                  NaN       NaN                           NaN   NaN
# 169                  NaN       NaN                           NaN   NaN
# 170                  NaN       NaN                           NaN   NaN
# 171                  NaN       NaN                           NaN   NaN
# 172                  NaN       NaN           Vogt Dirt Service     NaN
# 173              Crusher       NaN                           NaN   NaN
# 174                  NaN       NaN                           NaN   MN
# 175                  NaN   Surface                           NaN   NaN
# 176                  NaN       NaN                           NaN   NaN
# 177                  NaN       NaN                           NaN   NaN
# 178                  NaN       NaN                           NaN   NaN
# 179                  NaN       NaN                           NaN   NaN
#
#             Status
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6          Active
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15   Intermittent
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24   Intermittent
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# ..             ...
# 150  Intermittent
# 151            NaN
# 152            NaN
# 153            NaN
# 154            NaN
# 155            NaN
# 156            NaN
# 157            NaN
# 158            NaN
# 159  Intermittent
# 160            NaN
# 161            NaN
# 162            NaN
# 163            NaN
# 164            NaN
# 165            NaN
# 166            NaN
# 167            NaN
# 168  Intermittent
# 169            NaN
# 170            NaN
# 171            NaN
# 172            NaN
# 173            NaN
# 174            NaN
# 175            NaN
# 176            NaN
# 177  Intermittent
# 178            NaN
# 179            NaN
#
# [180 rows x 8 columns]

# %%
df.to_csv("dirt-operators-final.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
import pandas as pd
df = pd.read_csv('dirt-operators-final.csv')
df.head()
# Out:
#   Coal or Metal Commodity         ID            Mine Name Mine Type  \
# 0           NaN       NaN  3503598.0                  NaN       NaN
# 1           NaN       NaN        NaN                  NaN       NaN
# 2           NaN       NaN        NaN  Newberg Rock & Dirt       NaN
# 3           NaN       NaN        NaN                  NaN       NaN
# 4           NaN       NaN        NaN                  NaN   Surface
#
#                 Operator State Status
# 0                    NaN   NaN    NaN
# 1  Newberg Rock & Dirt     NaN    NaN
# 2                    NaN   NaN    NaN
# 3                    NaN   OR     NaN
# 4                    NaN   NaN    NaN
